# %% [markdown]
# <a href="https://colab.research.google.com/github/flxwxr/googlecolabsla/blob/main/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
while True:
  try:
    a = int(input("a: "))
    b = int(input("b:"))

    print(a + b)
    print(a - b)
    break

  except ValueError:
   print("ah, certeza?")
# Out:
# a: 443
# b:87654
# 88097
# -87211
